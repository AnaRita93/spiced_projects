# %%
import pandas as pd

# %%
df = pd.read_csv('/home/rita/Documents/spiced/spiced-projects/convex_capers_student_code/week01/data/gapminder_total_fertility.csv', index_col=0)

# %%
df.head(5)
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
df = df[['1950','1955','2000']]

# %%
df = df.loc[['Germany','India','Bulgaria','Kenya']]

# %%
from matplotlib import pyplot as plt
df.plot.bar(figsize=(5,7))
plt.savefig('bars.png')

# %%
df.plot.bar(y='1950', width=0.7, color='orange')

# %%
#Exercise 2: 

#sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
flights = sns.load_dataset("flights")
flights.head(5)

# Plot the responses for different events and regions
sns.lineplot(data = flights, x='year', y = 'passengers')
 #            hue="region", style="event",
  #           data=fmri)

# %%
import seaborn as sns
#sns.set_theme(style="darkgrid")
df = sns.load_dataset("penguins")
sns.displot(
    df, x="flipper_length_mm", col="species", row="sex",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
conda update --all
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/rita/anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py37_0           6 KB
#     _openmp_mutex-4.5          |            1_gnu          22 KB
#     anaconda-custom            |           py37_1           3 KB
#     anaconda-client-1.8.0      |   py37h06a4308_0         150 KB
#     anaconda-navigator-2.0.4   |           py37_0         5.1 MB
#     anaconda-project-0.10.1    |     pyhd3eb1b0_0         218 KB
#     anyio-2.2.0                |   py37h06a4308_1         123 KB
#     argon2-cffi-20.1.0         |   py37h27cfd23_1          46 KB
#     asn1crypto-1.4.0           |             py_0          80 KB
#     astroid-2.6.6              |   py37h06a4308_0         311 KB
#     astropy-4.3.1              |   py37h09021b7_0         6.3 MB
# ...

# %%
df = sns.load_dataset("penguins")
sns.displot(
    df, x="flipper_length_mm", col="species", row="sex",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-548dee6aee7b> in <module>
#       1 df = sns.load_dataset("penguins")
# ----> 2 sns.displot(
#       3     df, x="flipper_length_mm", col="species", row="sex",
#       4     binwidth=3, height=3, facet_kws=dict(margin_titles=True),
#       5 )
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
df = sns.load_dataset("penguins")
sns.displot(
    df, x="flipper_length_mm", col="species", row="sex",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)
